# %%
# 라이브러리
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import calendar
from datetime import datetime, timedelta

import os


# %matplotlib inline

# 경고메세지 팝업 끄기
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %% [markdown]
# # 데이터 불러오기

# %%
df=pd.read_csv('fda_train.csv')
df
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 0               0        0            b      2016-06-01           13:13
# 1               0        1            h      2016-06-01           18:12
# 2               0        2            c      2016-06-01           18:52
# 3               0        3            a      2016-06-01           20:22
# 4               0        4            c      2016-06-02           11:06
# ...           ...      ...          ...             ...             ...
# 6556608      2136  4663855            d      2019-02-28           23:20
# 6556609      2136  4663855            d      2019-02-28           23:24
# 6556610      2136  4663489            a      2019-02-28           23:24
# 6556611      2136  4663856            d      2019-02-28           23:27
# 6556612      2136  4658616            c      2019-02-28           23:54
#
#          installment_term  region type_of_business       amount
# 0                       0     NaN           기타 미용업  1857.142857
# 1                       0     NaN           기타 미용업   857.142857
# 2                       0     NaN           기타 미용업  2000.000000
# 3                       0     NaN           기타 미용업  7857.142857
# 4                       0     NaN           기타 미용업  2000.000000
# ...                   ...     ...              ...          ...
# 6556608                 0  제주 제주시           기타 주점업 -4500.000000
# 6556609                 0  제주 제주시           기타 주점업  4142.857143
# 6556610                 0  제주 제주시           기타 주점업  4500.000000
# 6556611                 0  제주 제주시           기타 주점업   571.428571
# 6556612                 0  제주 제주시           기타 주점업  5857.142857
#
# [6556613 rows x 9 columns]

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## amount 데이터 타입 변경

# %%
df['amount'] = df['amount'].astype(int)

# %% [markdown]
# ## 날짜 및 지역 관련 데이터 처리

# %%
df["date"] = df["transacted_date"]+ " " + df["transacted_time"]

# %%
df["date"]  = pd.to_datetime(df["date"])

# %% [markdown]
# ### 연, 월, 요일, 시간 , 휴일, 분기, 계절, 지역 데이터 분리

# %%
df["year"] = df["date"].dt.year
df["month"] = df["date"].dt.month
df["dayofweek"] = df["date"].dt.weekday # 0-월요일, 1-화요일
df["hour"] = df["date"].dt.hour

# %%
def holidays(dayofweek):
    if dayofweek in [0,1,2,3,4]:
        return "0"
    elif dayofweek in [5,6]:
        return "1"

df["holidays"] = df.dayofweek.apply(holidays)

# %%
# 분기
df["quarter"] = df["date"].dt.quarter

# %%
# 계절 
def season(month):
    season = 'winter'
    if 3 <= month <=5:
        season = 'spring'
    elif 6<= month <=8:
        season = 'summer'
    elif 9<= month <=11:
        season = 'fall'
    
    return season

df["season"] = df.month.apply(season)

# %%
df["sido"]= df["region"].str.split(" ").str[0]
df["city"]= df["region"].str.split(" ").str[1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6556613 entries, 0 to 6556612
# Data columns (total 19 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   store_id          int64
#  1   card_id           int64
#  2   card_company      object
#  3   transacted_date   object
#  4   transacted_time   object
#  5   installment_term  int64
#  6   region            object
#  7   type_of_business  object
#  8   amount            int32
#  9   date              datetime64[ns]
#  10  year              int64
#  11  month             int64
#  12  dayofweek         int64
#  13  hour              int64
#  14  holidays          object
#  15  quarter           int64
#  16  season            object
#  17  sido              object
#  18  city              object
# dtypes: datetime64[ns](1), int32(1), int64(8), object(9)
# memory usage: 925.4+ MB

# %%
df.head(3)
# Out:
#    store_id  card_id card_company transacted_date transacted_time  \
# 0         0        0            b      2016-06-01           13:13
# 1         0        1            h      2016-06-01           18:12
# 2         0        2            c      2016-06-01           18:52
#
#    installment_term region type_of_business  amount                date  year  \
# 0                 0    NaN           기타 미용업    1857 2016-06-01 13:13:00  2016
# 1                 0    NaN           기타 미용업     857 2016-06-01 18:12:00  2016
# 2                 0    NaN           기타 미용업    2000 2016-06-01 18:52:00  2016
#
#    month  dayofweek  hour holidays  quarter  season sido city
# 0      6          2    13        0        2  summer  NaN  NaN
# 1      6          2    18        0        2  summer  NaN  NaN
# 2      6          2    18        0        2  summer  NaN  NaN

# %% [markdown]
# ## 특일 데이터 적용

# %%
df.iloc[0]
# Out:
# store_id                              0
# card_id                               0
# card_company                          b
# transacted_date              2016-06-01
# transacted_time                   13:13
# installment_term                      0
# region                              NaN
# type_of_business                 기타 미용업
# amount                             1857
# date                2016-06-01 13:13:00
# year                               2016
# month                                 6
# dayofweek                             2
# hour                                 13
# holidays                              0
# quarter                               2
# season                           summer
# sido                                NaN
# city                                NaN
# transacted_date1    2016-06-01 00:00:00
# Name: 0, dtype: object

# %%
do = pd.read_csv('holiday.csv')
do
# Out:
#        일자 및 요일    요일구분     비고
# 0   2016-01-01  금요일        신정
# 1   2016-02-08  월요일        설날
# 2   2016-02-09  화요일        설날
# 3   2016-02-10  수요일        설날
# 4   2016-03-01  화요일       삼일절
# ..         ...     ...    ...
# 56  2019-09-13  금요일        추석
# 57  2019-10-03  목요일       개천절
# 58  2019-10-09  수요일       한글날
# 59  2019-12-25  수요일       성탄절
# 60  2019-12-31  화요일     연말휴장일
#
# [61 rows x 3 columns]

# %% [markdown]
# x=do[do["비고"]=='연말휴장일'].index
# do = do.drop(x)

# %%
### 2019년 3월 이후 데이터 삭제 (df데이터와 일수 맞추기 ) # 위에 것 안해도 됨
do = do.truncate(after = 49)

# %%
do = do.truncate(before = 8)

# %%
do.rename(columns={'일자 및 요일':'transacted_date'}, inplace=True)

# %%
do.rename(columns={'요일구분':'day'}, inplace=True)

# %%
do["date"] = pd.to_datetime(do["transacted_date"])

# %%
do["dayofweek"] = do["date"].dt.weekday
do
# Out:
#    transacted_date    요일구분          비고       date  dayofweek
# 0       2016-01-01  금요일             신정 2016-01-01          4
# 1       2016-02-08  월요일             설날 2016-02-08          0
# 2       2016-02-09  화요일             설날 2016-02-09          1
# 3       2016-02-10  수요일             설날 2016-02-10          2
# 4       2016-03-01  화요일            삼일절 2016-03-01          1
# 5       2016-04-13  수요일       국회의원 총선거 2016-04-13          2
# 6       2016-05-05  목요일           어린이날 2016-05-05          3
# 7       2016-05-06  금요일          임시공휴일 2016-05-06          4
# 8       2016-06-06  월요일            현충일 2016-06-06          0
# 9       2016-08-15  월요일            광복절 2016-08-15          0
# 10      2016-09-14  수요일             추석 2016-09-14          2
# 11      2016-09-15  목요일             추석 2016-09-15          3
# 12      2016-09-16  금요일             추석 2016-09-16          4
# 13      2016-10-03  월요일            개천절 2016-10-03          0
# 14      2017-01-27  금요일             설날 2017-01-27          4
# 15      2017-01-30  월요일       설날(대체휴일) 2017-01-30          0
# 16      2017-03-01  수요일            삼일절 2017-03-01          2
# 17      2017-05-01  월요일          근로자의날 2017-05-01          0
# 18      2017-05-03  수요일          석가탄신일 2017-05-03          2
# 19      2017-05-05  금요일           어린이날 2017-05-05          4
# 20      2017-05-09  화요일        대통령 선거일 2017-05-09          1
# 21      2017-06-06  화요일            현충일 2017-06-06          1
# 22      2017-08-15  화요일            광복절 2017-08-15          1
# 23      2017-10-02  월요일         임시 공휴일 2017-10-02          0
# 24      2017-10-03  화요일            개천절 2017-10-03          1
# 25      2017-10-04  수요일             추석 2017-10-04          2
# 26      2017-10-05  목요일             추석 2017-10-05          3
# 27      2017-10-06  금요일       추석(대체휴일) 2017-10-06          4
# 28      2017-10-09  월요일            한글날 2017-10-09          0
# 29      2017-12-25  월요일            성탄절 2017-12-25          0
# 30      2018-01-01  월요일             신정 2018-01-01          0
# 31      2018-02-15  목요일             설날 2018-02-15          3
# 32      2018-02-16  금요일             설날 2018-02-16          4
# 33      2018-03-01  목요일            삼일절 2018-03-01          3
# 34      2018-05-01  화요일          근로자의날 2018-05-01          1
# 35      2018-05-07  월요일     어린이날(대체휴일) 2018-05-07          0
# 36      2018-05-22  화요일          석가탄신일 2018-05-22          1
# 37      2018-06-06  수요일            현충일 2018-06-06          2
# 38      2018-06-13  수요일           지방선거 2018-06-13          2
# 39      2018-08-15  수요일            광복절 2018-08-15          2
# 40      2018-09-24  월요일             추석 2018-09-24          0
# 41      2018-09-25  화요일             추석 2018-09-25          1
# 42      2018-09-26  수요일       추석(대체휴일) 2018-09-26          2
# 43      2018-10-03  수요일            개천절 2018-10-03          2
# 44      2018-10-09  화요일            한글날 2018-10-09          1
# 45      2018-12-25  화요일            성탄절 2018-12-25          1
# 46      2019-01-01  화요일             신정 2019-01-01          1
# 47      2019-02-04  월요일             설날 2019-02-04          0
# 48      2019-02-05  화요일             설날 2019-02-05          1
# 49      2019-02-06  수요일             설날 2019-02-06          2

# %%
def holidays(dayofweek):
    if dayofweek in [0,1,2,3,4]:
        return "1"
    else:
        return "0"

do["holidays"] = do.dayofweek.apply(holidays)
do.head()
# Out:
#   transacted_date    요일구분   비고       date  dayofweek holidays
# 0      2016-01-01  금요일      신정 2016-01-01          4        1
# 1      2016-02-08  월요일      설날 2016-02-08          0        1
# 2      2016-02-09  화요일      설날 2016-02-09          1        1
# 3      2016-02-10  수요일      설날 2016-02-10          2        1
# 4      2016-03-01  화요일     삼일절 2016-03-01          1        1

# %%
do.drop(["day","date","dayofweek"], inplace = True)
do
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-c2da7db01076> in <module>
# ----> 1 do.drop(["요일구분","date","dayofweek"], inplace = True)
#       2 do
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['요일구분' 'date' 'dayofweek'] not found in axis"

# %%
df= pd.merge(df,do, how='outer', on='transacted_date')
df
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 0               0        0            b      2016-06-01           13:13
# 1               0        1            h      2016-06-01           18:12
# 2               0        2            c      2016-06-01           18:52
# 3               0        3            a      2016-06-01           20:22
# 4               1     1931            b      2016-06-01           13:31
# ...           ...      ...          ...             ...             ...
# 6556608      2136  4659988            f      2017-10-04           23:32
# 6556609      2136  4659465            f      2017-10-04           23:41
# 6556610      2136  4659989            d      2017-10-04           23:47
# 6556611      2136  4659710            g      2017-10-04           23:53
# 6556612      2136  4659990            e      2017-10-04           23:53
#
#          installment_term  region type_of_business  amount  \
# 0                       0     NaN           기타 미용업    1857
# 1                       0     NaN           기타 미용업     857
# 2                       0     NaN           기타 미용업    2000
# 3                       0     NaN           기타 미용업    7857
# 4                       0     NaN              NaN    1071
# ...                   ...     ...              ...     ...
# 6556608                 0  제주 제주시           기타 주점업    9571
# 6556609                 0  제주 제주시           기타 주점업    7000
# 6556610                 0  제주 제주시           기타 주점업    5000
# 6556611                 0  제주 제주시           기타 주점업    3785
# 6556612                 0  제주 제주시           기타 주점업    4142
#
#                        date  ...  dayofweek  hour  holidays_x  quarter  \
# 0       2016-06-01 13:13:00  ...          2    13           0        2
# 1       2016-06-01 18:12:00  ...          2    18           0        2
# 2       2016-06-01 18:52:00  ...          2    18           0        2
# 3       2016-06-01 20:22:00  ...          2    20           0        2
# 4       2016-06-01 13:31:00  ...          2    13           0        2
# ...                     ...  ...        ...   ...         ...      ...
# 6556608 2017-10-04 23:32:00  ...          2    23           0        4
# 6556609 2017-10-04 23:41:00  ...          2    23           0        4
# 6556610 2017-10-04 23:47:00  ...          2    23           0        4
# 6556611 2017-10-04 23:53:00  ...          2    23           0        4
# 6556612 2017-10-04 23:53:00  ...          2    23           0        4
#
#          season  sido city transacted_date1   비고 holidays_y
# 0        summer   NaN  NaN       2016-06-01  NaN        NaN
# 1        summer   NaN  NaN       2016-06-01  NaN        NaN
# 2        summer   NaN  NaN       2016-06-01  NaN        NaN
# 3        summer   NaN  NaN       2016-06-01  NaN        NaN
# 4        summer   NaN  NaN       2016-06-01  NaN        NaN
# ...         ...   ...  ...              ...  ...        ...
# 6556608    fall    제주  제주시       2017-10-04   추석          1
# 6556609    fall    제주  제주시       2017-10-04   추석          1
# 6556610    fall    제주  제주시       2017-10-04   추석          1
# 6556611    fall    제주  제주시       2017-10-04   추석          1
# 6556612    fall    제주  제주시       2017-10-04   추석          1
#
# [6556613 rows x 22 columns]

# %% [markdown]
# ### merge 관련 결측치 정리

# %%
df["비고"] = df["비고"].fillna('.')

# %%
df["holidays_y"] = df["holidays_y"].fillna('0')
df.sample(3)
# Out:
#    store_id  card_id card_company transacted_date transacted_time  \
# 0         0        0            b      2016-06-01           13:13
# 1         0        1            h      2016-06-01           18:12
# 2         0        2            c      2016-06-01           18:52
#
#    installment_term region type_of_business  amount                date  ...  \
# 0                 0    NaN           기타 미용업    1857 2016-06-01 13:13:00  ...
# 1                 0    NaN           기타 미용업     857 2016-06-01 18:12:00  ...
# 2                 0    NaN           기타 미용업    2000 2016-06-01 18:52:00  ...
#
#    dayofweek  hour  holidays_x  quarter  season  sido city transacted_date1  \
# 0          2    13           0        2  summer   NaN  NaN       2016-06-01
# 1          2    18           0        2  summer   NaN  NaN       2016-06-01
# 2          2    18           0        2  summer   NaN  NaN       2016-06-01
#
#   비고 holidays_y
# 0  .          0
# 1  .          0
# 2  .          0
#
# [3 rows x 22 columns]

# %%
df = df.astype({'holidays_x':'int', 'holidays_y':'int'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6556613 entries, 0 to 6556612
# Data columns (total 22 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   store_id          int64
#  1   card_id           int64
#  2   card_company      object
#  3   transacted_date   object
#  4   transacted_time   object
#  5   installment_term  int64
#  6   region            object
#  7   type_of_business  object
#  8   amount            int32
#  9   date              datetime64[ns]
#  10  year              int64
#  11  month             int64
#  12  dayofweek         int64
#  13  hour              int64
#  14  holidays_x        int32
#  15  quarter           int64
#  16  season            object
#  17  sido              object
#  18  city              object
#  19  transacted_date1  datetime64[ns]
#  20  비고                object
#  21  holidays_y        int32
# dtypes: datetime64[ns](2), int32(3), int64(8), object(9)
# memory usage: 1.1+ GB

# %%
def holidays(holidays_x, holidays_y):
    if df7['holidays_x'] + df7['holidays_y']  >=1 :
        return "1"
    else df7['holidays_x'] + df7['holidays_y']< 1 :
        return "0"

do["holidays"] = do.dayofweek.apply(holidays)
do.head()
# Out:
#   File "<ipython-input-171-a0e4ecb43316>", line 4
#     else holidays_x + holidays_y < 1 :
#          ^
# SyntaxError: invalid syntax

# %%
df7['holidays_x'] + df7['holidays_y']  >=1

# %% [markdown]
# ## 결측치 제거

# %% [markdown]
# ### region 과 type_of_business의 결측치
# * region과 type_of_business 중에 1개라도 결측치면 제거
# * 전체 데이터 중 약 40% 남음

# %%
# missing data
total = df.isnull().sum().sort_values(ascending =False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total','Percent'])
missing_data.head(10)

# %%
df[df["region"].isnull() | df["type_of_business"].isnull()]

# %%
df_0=df[df["region"].isnull() | df["type_of_business"].isnull()].index
df = df.drop(df_0)

# %%
df.isnull().sum()

# %%
df_2.info()

# %%
# missing data check
total = df_2.isnull().sum().sort_values(ascending =False)
percent = (df_2.isnull().sum()/df_2.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total','Percent'])
missing_data.head(10)

# %%
df.shape

# %%
2318410 - 22

# %% [markdown]
# ### (N/Y)amount 값 중  환불데이터가 아닌 음수인 값 제거

# %%
test = df.groupby(['store_id','card_id'],)['amount'].sum().to_frame()
test

# %%
test0 = test[test['amount']<0]
test0.shape

# %%
df[df.index == 322529]

# %%
 test[test['amount']<0]

# %%
df[(df["store_id"]==142) & (df["card_id"]==322529)]

# %%
df[(df["store_id"]==496) & (df["card_id"]==306712)]

# %%
df[(df["store_id"]==616) & (df["card_id"]==1197724)]

# %%
df[(df["store_id"]==770) & (df["card_id"]==1617416)]

# %%
df[(df["store_id"]==838) & (df["card_id"]==1785941)]

# %%
df[(df["store_id"]==838) & (df["card_id"]==1785956)]

# %%
df[(df["store_id"]==892) & (df["card_id"]==1896816)]

# %%
df[(df["store_id"]==977) & (df["card_id"]==2100492)]

# %%
df[(df["store_id"]==1100) & (df["card_id"]==2374816)]

# %%
df[(df["store_id"]==1354) & (df["card_id"]==2920340)]

# %%
df[(df["store_id"]==1366) & (df["card_id"]==2940184)]

# %%
df[(df["store_id"]==1538) & (df["card_id"]==3330482)]

# %%
df[(df["store_id"]==1637) & (df["card_id"]==1537277)]

# %%
df[(df["store_id"]==1637) & (df["card_id"]==3549990)]

# %%
df[(df["store_id"]==1670) & (df["card_id"]==3593810)]

# %%
df[(df["store_id"]==1917) & (df["card_id"]==4138817)]

# %%
df[(df["store_id"]==1957) & (df["card_id"]==4232623)]

# %%
df[(df["store_id"]==2128) & (df["card_id"]==4644633)]

# %%
df.index

# %%
df[df.index == 322529]

# %% [markdown]
# ##  type_of_business 전처리

# %% [markdown]
# ### 중분류 컬럼 만들기

# %%
df['type_of_business'].unique()

# %%
biz = pd.read_csv('businesstype.csv')
biz

# %%
biz.fillna(method='ffill')

# %%
for i in range(len(df)):
    for j in range(len(biz)):
        if df['type_of_business'][i] == biz['Unnamed: 9'][j] :
            df['type_of_business'][i] = biz['Unnamed: 1'][j]

# %% [markdown]
# * 데이터 분리 완료 (다음에 할 때는 비슷한 요소끼리 모으기)

# %%
df.to_csv('funda_data.csv', index= False)

# %%
df=pd.read_csv('funda_data.csv')
df
